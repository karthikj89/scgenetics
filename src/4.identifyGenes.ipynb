# %%
import scanpy as sc
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
pd.set_option('display.max_rows', 50)

# %% [markdown]
# # load all the data files

# %%
MAGMA_PATH='/ahg/regevdata/projects/scgwas/data/avivalkes_grant/results/magma/MAGMA_v108_GENE_10_ZSTAT.v2.txt'

def load_magma():
    magma_scores = pd.read_csv(MAGMA_PATH, sep='\t').T
    magma_scores = magma_scores.fillna(0)
    return magma_scores

def compute_celltypeprogram_genes(magma_scores, celltype, trait, programtype, tissue=None, nmfprogram=None, status=None):
    MODULE_DIR='/ahg/regevdata/projects/scgwas/data/singlecell/modules/'
    if programtype=='healthytopics':
        module_scores = pd.read_csv(MODULE_DIR + 'nmf_membership/nmf_corprogram_healthy_new/%s/%s_corprog_%d.txt'%(tissue,tissue, nmf_program+1), sep='\t', header=None)
        module_scores = module_scores.set_index(module_scores.columns[0])
        module_scores = module_scores.reset_index()
    elif programtype=='jointtopics':
        module_scores = pd.read_csv(MODULE_DIR + '/nmf_membership/nmf_corprogram_shared_new/%s/nmf_%s%s.txt'%(tissue, status, nmf_program+1), sep='\t', header=None)
        module_scores = module_scores.set_index(module_scores.columns[0])
        module_scores = module_scores.reset_index()
    else:
        module_scores = pd.read_csv(MODULE_DIR+ '/' + programtype + '/celltypeenriched_L2/%s_L2.txt'%celltype, sep='\t', header=None)
        celltype = celltype.split('/')[1]
    module_scores.columns = ['Gene', 'score']
    if len(module_scores[module_scores.score >= 0.8].Gene.values) > 150:
        magma_subset = magma_scores[set(magma_scores.columns).intersection(module_scores[module_scores.score >= 0.8].Gene.values)]
    else:
        magma_subset = magma_scores[set(magma_scores.columns).intersection(module_scores.sort_values(by='score', ascending=False)[0:150].Gene.values)]
    magma_trait = magma_subset[magma_subset.index==trait].values
    trait_argsort = np.argsort(magma_trait)
    top_genes = np.array(magma_subset.columns)[trait_argsort]
    top_genes = top_genes.tolist()[0][::-1][0:50]
    return top_genes

# %% [markdown]
# # cell types

# %%
celltype_trait_pairs = [('PASS_Celiac', 'zheng_pbmc/T_Lymphocytes'),
                        ('PASS_Ulcerative_Colitis', 'zheng_pbmc/B_Lymphocytes'),
                        ('PASS_Alzheimers_Jansen2019', 'zheng_pbmc/Monocytes'),
                        ('PASS_Alzheimers_Jansen2019', 'zheng_pbmc/DC'),
                        ('PASS_Alzheimers_Jansen2019', 'alzheimers_brain/Microglia'),
                        ('PASS_MDD_Wray2018', 'brain/GABAergic'), 
                        ('PASS_Intelligence_SavageJansen2018', 'brain/Glutamatergic'),
                        ('PASS_Insomnia_Jansen2019', 'brain/Glutamatergic'),
                        ('UKB_460K.biochemistry_TotalBilirubin', 'liver/Epithelial'),
                        ('UKB_460K.biochemistry_Creatinine', 'kidney/Connecting_tubule'),
                        ('PASS_AtrialFibrillation_Nielsen2018', 'heart/Atrial_Cardiomyocyte'),
                        ('UKB_460K.bp_SYSTOLICadjMEDz', 'heart/Pericyte'),
                        ('UKB_460K.bp_DIASTOLICadjMEDz', 'heart/Pericyte'),
                        ('UKB_460K.bp_SYSTOLICadjMEDz', 'heart/Smooth_Muscle'),
                        ('UKB_460K.bp_DIASTOLICadjMEDz', 'heart/Smooth_Muscle'), 
                        ('UKB_460K.lung_FEV1FVCzSMOKE', 'kropski_lung/Fibroblasts'), 
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 'kropski_lung/T_Lymphocytes'),
                        ('PASS_IBD_deLange2017', 'xavier_colon/Endothelial'),
                        ('PASS_IBD_deLange2017', 'xavier_colon/M_cells'), 
                        ('PASS_UC_deLange2017', 'xavier_colon/Enteroendocrine'),
                        ('UKB_460K.body_WHRadjBMIz', 'xavier_colon/Fibroblast'),
                        ('UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED', 'skin/Langerhans_cells'),
                        ('UKB_460K.body_WHRadjBMIz', 'adipose/Fat')]

# %%
monogenic_genes = 'ADA,ALPI,ANKZF1,ARPC1B,BACH2,BCL10,BTK,CD3G,CD40LG,CD55,COL7A1,CTLA4,CYBA,CYBB,DCLRE1C,DKC1,DOCK2,FERMT1,FOXP3,G6PC3,GUCY2C,HPS1,HPS3,HPS4,ICOS,IKBKG,IL10,IL10RA,IL10RB,IL21,IL2RA,IL2RG,IRF2BP2,ITCH,ITGB2,LACC1,LIG4,LRBA,MALT1,MASP2,MVK,NCF1,NCF2,NCF4,NFAT5,NLRC4,NPC1,PIK3CD,PIK3R1,POLA1,RAG1,RAG2,RBCK1,RELA,RIPK1,RTEL1,SIRT1,SKIV2L,SLC26A3,SLC37A4,SLC9A3,SLCO2A1,STAT1,STAT3,STIM1,TGFB1,TGFBR1,TGFBR2,TNFAIP3,TRIM22,TRNT1,TTC37,TTC7A,TYMP,WAS,WIPF1,XIAP,ZAP70'
monogenic_genes = monogenic_genes.split(',')

# %%
magma_scores = load_magma()
for trait, celltype in celltype_trait_pairs:
    topgenes = compute_celltypeprogram_genes(magma_scores, celltype, trait, 'healthy')
    print("%s\t%s\t%s"%(trait, celltype, ','.join(topgenes)))
# Out:
# PASS_Celiac	zheng_pbmc/T_Lymphocytes	ETS1,CD247,CD28,RCAN3,ANKRD12,TXK,ANXA6,LBH,C12orf75,UBASH3A,PA2G4,C11orf58,NDFIP1,PYHIN1,GRAP2,RPL18,APRT,SOCS3,TNFAIP8,DSTN,RPL6,RORA,RAC2,LAT,PTPRCAP,TAF7,STMN1,BCL11B,HINT1,LEF1,RPS25,GZMK,PRR5,RPA2,SOD1,TMEM173,RGS10,ANXA2R,RPS20,SKAP1,GOLGA7,B2M,CCR7,TRAT1,RBL2,GATA3,HNRNPK,ARHGDIB,RPL35A,TERF2IP
# PASS_Ulcerative_Colitis	zheng_pbmc/B_Lymphocytes	REL,GPX1,LSP1,IMPDH2,FAM26F,EIF6,BRK1,SHMT2,NFKBIA,LAPTM5,RPL23A,CTSS,BANK1,PRKCB,MS4A1,HHEX,ALOX5,CCDC50,TCF4,RPS5,ENSA,AFF3,RPS13,USF2,SLC50A1,SCIMP,CD19,DUSP1,DBNL,FAU,ARID5B,ZFP36L1,SELL,NCF4,ADK,PLAC8,RPL23,RPL28,EZR,PPAPDC1B,LSM10,PKIG,AKR1A1,PRR13,RNASET2,BLOC1S2,POU2F2,RPS11,WHSC1L1,LTA4H
# PASS_Alzheimers_Jansen2019	zheng_pbmc/Monocytes	MS4A6A,MS4A4A,CD33,FCER1G,LILRA5,TMEM219,ALDOA,PILRA,PPM1N,ZYX,GMFG,ORAI3,FOSB,CTSH,ABI3,SPI1,ERCC1,NDUFA2,SUPT4H1,LAMTOR4,LACTB,VASP,GRN,SCIMP,SLC16A3,SYK,LILRB2,RAC1,SRGN,LILRB4,SHKBP1,RRBP1,CLTA,LRRC25,PYCARD,COX8A,RIN3,LILRB1,GAPDH,SIDT2,ITGAL,RASSF4,SLC12A9,TAGLN,CD14,PPP4C,FCGR2A,COX5A,ROGDI,SQSTM1
# PASS_Alzheimers_Jansen2019	zheng_pbmc/DC	MS4A6A,TRAPPC6A,CD33,VKORC1,FCER1G,UFC1,CCDC85B,FIBP,PSMC3,NDUFS2,PFDN2,TMEM219,ALDOA,PILRA,PHB,ZYX,GMFG,ORAI3,FOSB,CTSH,ABI3,SPI1,ERCC1,ATPAF2,NDUFA2,SUPT4H1,PTPMT1,APP,LAMTOR4,LACTB,VASP,PSMB5,GRN,SYK,SLC25A11,MBOAT7,RAC1,SRA1,SRGN,CACNA2D3,LILRB4,LMAN2,SHKBP1,RTFDC1,RRBP1,MTCH2,CLTA,PFN1,LRRC25,UBE2L3
# PASS_Alzheimers_Jansen2019	alzheimers_brain/Microglia	MS4A6A,APOE,PLCG2,ITGAX,ITGAM,SYK,SRGN,TNS3,RIN3,LHFPL2,BLNK,SLC2A5,SAMSN1,ZC3HAV1,CD14,FKBP5,FCGR2A,CYTH4,ARHGAP25,MEF2A,PRKCH,AXL,TNFRSF1B,LAPTM5,SFMBT2,LCP2,CPVL,RUNX2,SLC4A7,ARHGAP31,EPSTI1,CX3CR1,LPAR6,CD74,CSF3R,PADI2,SLC11A1,TMC8,PALD1,C10orf54,LAT2,CHST11,DENND3,FCHSD2,ST6GAL1,FCGBP,ATP8B4,ZNF710,LYN,FGD4
# PASS_MDD_Wray2018	brain/GABAergic	TCF4,BEND4,TMX2,PCLO,ZNF462,TAOK3,MAP7D1,TMEM106B,ADARB1,SEMA6D,NYAP2,CHRM2,RTN1,CCDC152,ASTN2,GPX1,GABRA1,NTM,CKAP2,ZNF608,HSBP1L1,SRRM4,C7orf72,EYS,GRIA1,ERBB4,TCAIM,PTPRN,SERPINI1,PSME2,C1QTNF7,RAPGEF4,ROBO2,MEGF11,SEC61G,SPCS1,CC2D2A,SGCZ,B4GALT6,CNTNAP5,NMNAT2,RPS27,NTRK2,BICD1,TMEM50B,CDH9,ZPBP,SMARCA4,PER3,BRE
# PASS_Intelligence_SavageJansen2018	brain/Glutamatergic	DCC,RBFOX1,NEGR1,CCDC101,DAG1,DDN,SULT1A2,CLN3,RNF123,ATXN2L,MGAT3,CSE1L,TRAIP,DPP4,ZNF638,RHOA,NKIRAS1,MGEA5,GBF1,EXOC4,LONRF2,AKTIP,CAMKV,CALN1,MON1A,RUNX1T1,MTMR4,RBM6,APEH,CHST10,MYBPHL,NFATC2IP,GATB,SMIM4,PPM1E,UBE2E1,TRIM37,THRB,BAG5,SND1,MEF2C,AMT,TUFM,PFDN1,KMT2D,PRKAG1,DBN1,PRR7,SHISA9,NICN1
# PASS_Insomnia_Jansen2019	brain/Glutamatergic	LIN28B,NMT1,DNPH1,CNIH2,CUL9,TMEM151A,RAB1B,FOXP2,KLC2,MEIS1,MFSD1,RARRES1,NADK,TRPC7,KDM4B,SMAD5,LOC100287290,ACBD4,DCAKD,NFE2L1,KLHDC8B,GOLGA2,CCDC71,INHA,STAU1,PTPRD,UBE2W,GFM1,LRFN5,TMEM161B,IPO9,ZNF521,CHCHD3,GNB1,SNX11,HEXIM1,GIN1,SLC35E2,NLRP9,LXN,PPIP5K2,CCDC106,PTGER3,ZNF585A,PSMC3,MNT,CBX1,NRXN3,RASGRP1,CFAP74
# UKB_460K.biochemistry_TotalBilirubin	liver/Epithelial	ERP29,MPST,APOA5,ANGPTL3,SLC22A18,SLC2A2,ALDH2,AKR1C4,GPAM,SLCO1B1,ADH5,SLC22A1,APOC1,ADH4,AKR1C3,NDUFAF3,TMPRSS6,SPP2,PCCB,TST,CYB5A,MRPL24,GNMT,NUPR1,HNF4A,SLC51A,HSD17B13,SULT1A1,GADD45G,RAB13,CHP1,TUFM,LEPR,ROMO1,SPRYD4,AKR1A1,MLXIPL,SAT2,APOE,CERS2,DDT,SLC22A7,CDH1,PSMB5,PDCD5,S100A13,PGRMC2,CFI,FAM96A,CYP3A5
# UKB_460K.biochemistry_Creatinine	kidney/Connecting_tubule	KNG1,CA12,JUND,RBM47,STC1,NFE2L2,RCN2,C1orf54,MAFF,ATP1B3,TBX2,MAP1LC3A,MECOM,TFCP2L1,TFDP2,MRPL33,TRIB1,CASZ1,ERBB4,SPTBN1,PPP2R3A,OGDHL,PPARGC1A,DCDC2,MITF,HSP90AA1,GNAS,GBAS,NR0B2,RBM39,TMA7,PKHD1,ARL15,OVOL1,TNRC6B,DACH1,ERBB2,CHD9,ATRAID,COL18A1,MCL1,ARHGAP24,COLCA1,AFF4,MUC1,ARG2,PNISR,IVNS1ABP,LRRFIP1,CWH43
# PASS_AtrialFibrillation_Nielsen2018	heart/Atrial_Cardiomyocyte	CAV2,PKD2L2,FAM13B,CAV1,PPFIA4,CPEB4,CASQ2,SPATS2L,GBF1,MYH6,TBX5,CFL2,PCM1,HCN4,ASAH1,KCNH2,KCND3,KCNN2,ZNF292,TTN,SMIM8,CAMK2D,CAND2,ATXN1,NKX2-5,CDK6,KLHL3,SSPN,SAMD8,FRMD4B,MYOT,FBXO32,USP34,DPF3,HIP1R,AKAP6,IGF1R,ERBB2,SCN5A,UBE2D3,TMEM40,CASZ1,GTF2I,ZBTB38,NUCKS1,MURC,C10orf76,SCMH1,MYO18B,COPS4
# UKB_460K.bp_SYSTOLICadjMEDz	heart/Pericyte	PLCE1,TNS1,GUCY1A3,ARHGAP42,TBX2,FHL5,TNS2,EBF2,MRVI1,EBF1,ENPEP,SETBP1,SEPT9,DCBLD1,MKLN1,ZBTB46,NBEAL1,NGF,EDNRA,BCAS3,CACNA1C,SGIP1,PDE8A,ADCY3,AGT,EPOR,SOX13,COBLL1,THSD7B,GUCY1B3,RGL3,PRKG1,CDC42BPA,HIGD1B,FAM213A,JAG1,PDE1A,HIP1,SLC12A2,DOCK6,INPP4B,ANKS1A,CENPO,PTH1R,GJA4,DENND2A,WISP1,APOLD1,BCAM,ZEB2
# UKB_460K.bp_DIASTOLICadjMEDz	heart/Pericyte	MRVI1,ARHGAP42,CDC42BPA,TNS1,JAG1,ABO,PLCE1,ZBTB46,ENPEP,SETBP1,MKLN1,EBF1,NGF,RGL3,SEPT9,CACNA1C,EPOR,TBX2,GUCY1B3,CENPO,SOX13,BCAS3,PDE1A,GUCY1A3,ADCY3,GPAT2,AGT,TRAK1,TNS2,ANO1,WISP1,EBF2,LMOD1,PRKG1,NOTCH3,DENND2A,RBPMS,SOX5,COX4I2,BCL2L1,TCF4,ANKS1A,ISYNA1,RERG,ARHGEF17,KALRN,INPP4B,COL5A3,THSD7B,COBLL1
# UKB_460K.bp_SYSTOLICadjMEDz	heart/Smooth_Muscle	CACNB2,SLC4A7,TNS1,GUCY1A3,TBX2,FERMT2,FHL5,MRVI1,EBF1,ENPEP,SETBP1,PRDM16,SEPT9,VCL,TCF7L2,HERC4,FN1,MYO9B,CAMK2G,COL21A1,NBEAL1,JPH2,EDNRA,BCAS3,ARHGEF26,ARID5B,VGLL4,KIF5B,CACNA1C,FRYL,TMEM165,TPM1,SGIP1,ADCY3,CELF1,CNNM2,SGCD,AFAP1,CDKAL1,RGS7BP,GEM,FAM13A,GLS,PTPRD,SLC8A1,CCDC6,CLIC4,ITGA9,COBLL1,RGL3
# UKB_460K.bp_DIASTOLICadjMEDz	heart/Smooth_Muscle	CACNB2,TMEM165,MRVI1,CELF1,MYO9B,LIMA1,PRDM16,TNS1,SLC4A7,JAG1,MICAL3,ENPEP,COL4A1,SETBP1,ARHGEF26,SLC8A1,EBF1,PDE5A,CFAP69,RGL3,SEPT9,CACNA1C,ACTN4,TBX2,BCAS3,GUCY1A3,PDE1A,CLIC4,CNNM2,SLMAP,ADCY3,FERMT2,CDKAL1,COL4A2,PHLDB2,GLS,ANO1,FRK,ZHX3,FAM13A,LMOD1,COL1A1,MYOCD,SPEG,PRKG1,COL21A1,NOTCH3,TRPC4,RSRC1,YAP1
# UKB_460K.lung_FEV1FVCzSMOKE	kropski_lung/Fibroblasts	LOX,DTWD1,NEXN,MRC2,CALD1,ADAMTS2,HTRA1,LRP1,FGF7,RERG,ITGAV,DNAJB4,MACF1,LTBP1,COL4A2,EFEMP1,LMCD1,LTBP4,DST,PLXDC2,LTBP2,RHOBTB3,ADAMTS5,PDZRN3,SFRP2,ARF4,MAP1LC3A,TIMP3,ANTXR1,IL1R1,SMAD3,ZFP36L2,P4HA2,COL16A1,MFAP2,TGFBR3,ITGA1,RBMS3,PHLDB2,PRSS23,HOXB2,SERPING1,CDKN2C,FAM3C,IFITM1,COPZ2,HIC1,IFITM2,ADD3,CNPY4
# PASS_ChildOnsetAsthma_Ferreira2019	kropski_lung/T_Lymphocytes	CAMK4,GPR18,DEF6,PRKCQ,FMNL1,MEI1,STMN3,PHF19,RORA,TRAF1,GFI1,IRF1,LBH,THEMIS,CD52,FAM69A,ABI3,TOP2A,GPR132,RGS14,KIAA0391,UBASH3A,PRR5L,BCL2,CD247,LIME1,ATP8B2,DDX6,IL18RAP,TGFBR3,CREM,IL18R1,SLAMF1,IL21R,SLFN5,TAGAP,ETS1,STK4,PRKCB,RPAP2,GLMN,RUNX3,CTSW,CELF2,AKNA,RCSD1,BATF,USP28,CXCR6,FASLG
# PASS_IBD_deLange2017	xavier_colon/Endothelial	RHOA,PDLIM4,STARD3,CCL2,STAT3,SERBP1,IRF1,PARK7,ZFP36L1,GPX1,KLHDC8B,NKX2-3,NDFIP1,LAMB2,PTRF,CDC37,SCAMP3,EFNA1,NDUFAF3,PRMT1,ANKRD65,POLR2E,PLAU,HHEX,TSPAN14,CD40,CERS2,TNFRSF4,TGFBR2,ADM5,RHOC,NFKBIA,GPX4,UBE2F,DGKE,CRK,BAG3,IFITM2,VWA1,CCND3,ETS1,HOXD1,TCF4,RBMS1,MYO1C,SHISA5,IFITM1,RAB5C,CCND1,NUCKS1
# PASS_IBD_deLange2017	xavier_colon/M_cells	UQCR10,FERMT1,PPP1R1B,CCL20,RAB25,NXPE4,TSPO,CLDN3,TALDO1,CLDN4,CDX1,SELENBP1,EIF3K,SPINT2,CHCHD10,ATP5D,AP1M2,STARD10,COX5B,GOLM1,ASL,LGALS9,NOXO1,SRCAP,PDAP1,RAB32,ATP5E,ECHS1,MDH2,CYSTM1,ANXA11,ETFB,MUC13,PRR13,PERP,BLVRB,HMGCS2,MRPL52,CTSE,CLDN7,PPP4C,ALDOA,PSMA5,PPDPF,NDUFB1,GGH,C15orf48,ANXA2,CHCHD5,LGALS3
# PASS_UC_deLange2017	xavier_colon/Enteroendocrine	UQCR10,UQCRC1,CLDN3,CLDN4,PNKD,PPP1R1B,AURKAIP1,DCTPP1,DBI,TSPAN1,FXYD3,CDX1,NDUFA13,CHCHD10,KRTCAP3,CISD1,PIGR,ACTG1,MDH2,DDC,ECHDC2,UQCR11,CKB,KIF12,LXN,TXNDC17,BAG1,COX6A1,LGALS9,TMEM261,SNRPB,TSTD1,TTR,ATP5J2,STARD10,CLDN7,FAM213A,NEUROD1,ATP5E,HMGCS2,ATP5G3,SPINT2,COX5B,LAMTOR4,CYSTM1,GCG,PRDX2,S100A10,SERINC2,HSPD1
# UKB_460K.body_WHRadjBMIz	xavier_colon/Fibroblast	FGFR4,TFPI,PIGC,VASN,C6orf1,HSPB2,TBX2,TMEM165,SDHD,TCEA2,PAM,LAMB1,AHNAK,COL4A2,HOXA10,TWF2,LAMB2,CYTL1,PEPD,CPED1,RBPJ,IP6K2,SAT2,BAD,SSPN,CRYAB,SRPK2,TNFSF12,NFIX,COL6A2,TPPP3,ADM,ARID5B,HMGXB4,HOXA11,NID1,UBXN1,IMPDH2,NDUFAF3,GPX1,REEP2,CCND1,WNT4,HHIP,PLXND1,JAZF1,LOXL1,TIMP2,PML,ACTR10
# UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED	skin/Langerhans_cells	IL1R1,RUNX3,FCER1G,NFATC2,NDFIP1,IL18R1,RASA2,REL,UBE2E2,DRAP1,PLXNC1,HCLS1,EAF2,APOBR,HSPE1,ARL6IP4,RIN3,ARHGAP15,GPR183,LAMTOR2,CFL1,RILPL2,FNDC4,FPR3,TMED5,PRKCB,NR4A2,TMEM156,KYNU,RASSF5,CSGALNACT2,ARRDC2,CNTRL,CIITA,ZFHX3,ANKRD44,SCNM1,SCAMP2,TYMP,ZMIZ1,ATPAF2,PTPRC,FAM109A,CD52,TNFAIP3,ICAM3,CSK,FES,DEF6,FCGRT
# UKB_460K.body_WHRadjBMIz	adipose/Fat	MLXIPL,EML3,FAM13A,PPP2R1B,VEGFA,PNPLA2,COL4A2,CRYAB,PCK1,COL4A1,AKR1C1,RBP4,LPL,LAMA4,STAT5A,ADCK3,ITGA7,PDE3B,PHLDB2,AKR1C2,IGF1,PLIN4,TNRC6A,THRSP,GPAM,MAST4,SLC7A6,FZD4,EBF1,LVRN,AGPAT2,MARC1,ITIH5,CD36,ADH1B,FASN,AKR1C3,PTPRS,ACADVL,ALDH1L1,GPT2,DDX17,CAV1,ITSN1,LIPE,TNS1,NKTR,RDH5,KCNIP2,CIDEC

# %% [markdown]
# # Disease progression cell types

# %%
celltype_trait_pairs = [('PASS_UC_deLange2017', 'UC/Disease_T_Lymphocytes'),
                        ('PASS_IBD_deLange2017', 'UC/Disease_T_Lymphocytes'),
                        ('PASS_UC_deLange2017', 'UC/Disease_Enterocytes'),
                        ('PASS_UC_deLange2017', 'UC/Disease_TA'),
                        ('PASS_UC_deLange2017', 'UC/Disease_M_cells'),
                        ('PASS_IBD_deLange2017', 'UC/Disease_T_Lymphocytes'),
                        ('PASS_IBD_deLange2017', 'UC/Disease_M_cells'),
                        ('PASS_Multiple_sclerosis', 'MS/Disease_GABAergic'), 
                        ('PASS_Multiple_sclerosis', 'MS/Disease_Glia'),
                        ('PASS_Multiple_sclerosis', 'MS/Disease_Endothelial'),
                        ('PASS_Multiple_sclerosis', 'MS/Disease_Microglia'),
                        ('PASS_Alzheimers_Jansen2019', 'Alzheimers/Disease_Microglia'),
                        ('UKB_460K.lung_FEV1FVCzSMOKE', 'asthma_disease/Fibroblast'),
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 'asthma_disease/T_Lymphocyte'),
                        ('IPF_Allen2020', 'Fibrosis/Disease_Mucous')
                       ]

# %%
for trait, celltype in celltype_trait_pairs:
    topgenes = compute_celltypeprogram_genes(magma_scores, celltype, trait, 'disease')
    print("%s\t%s\t%s"%(trait, celltype, ','.join(topgenes)))
# Out:
# PASS_UC_deLange2017	UC/Disease_T_Lymphocytes	REL,STAT3,GPX1,ZFP36L1,LEF1,PRKCB,NUCKS1,TRPS1,FYB,ITLN1,CREM,SELL,CYTH1,RPLP2,TNFRSF25,NR3C1,BRD7,NDFIP1,GLCCI1,NFKB1,CAPZA1,SMCHD1,CTNNB1,CD44,PRDM1,RPS21,TNFRSF4,NSD1,PIM3,USF2,POLR2B,BATF,TNRC6B,ARID5A,CHD2,PDCD4,BPTF,ICA1,FAM107B,C6orf62,SRSF9,SLFN5,ETS1,RBPJ,YPEL3,ITGB2,DYNLL1,PCSK7,ASH1L,RNF168
# PASS_IBD_deLange2017	UC/Disease_T_Lymphocytes	REL,CYLD,BRD7,CREM,STAT3,ZFP36L1,GPX1,LNPEP,NDFIP1,ITLN1,RPL37,ASH1L,SMCHD1,TNFRSF4,PTPRC,SELL,TNFRSF25,ETS1,TMEM258,CYTH1,VMP1,BRD4,NUCKS1,PRKCB,BATF,IRF2BP2,TNFRSF18,FYB,TRPS1,FAM89B,PRDM1,CAPZA1,CTNNB1,HSPE1,MSI2,DNAJC7,SKP1,CDC42SE2,HSPD1,PIM3,NSD1,RPL9,RPS29,USF2,SON,TCF7,CCR7,HINT1,PDCD1,PPP1CB
# PASS_UC_deLange2017	UC/Disease_Enterocytes	C1orf106,REL,RHOA,APEH,GPR35,DLD,GSDMB,STAT3,TNFRSF14,DAG1,GPX1,RNF186,NDUFAF3,SEC16A,NR5A2,RBM5,FAM213B,RBM6,PEX13,UBA7,MED24,MST1R,NXPE1,ERRFI1,AHSA2,USP34,APOBR,CCL20,MTX1,MUC1,SERBP1,PTPN2,CLN3,KRTCAP2,HMGXB4,ZFP91,QARS,ZFP36L1,SMARCE1,CHP1,PDXDC1,HNF4A,MAPKAPK2,NUPR1,LPP,LMAN2,MRPL20,IL1R2,KIAA1109,BECN1
# PASS_UC_deLange2017	UC/Disease_TA	C1orf106,TNFSF15,PSMG1,REL,LAMB1,RHOA,SDCCAG3,APEH,GPR35,PMPCA,DLD,GSDMB,TCTA,STAT3,ARFRP1,TNFRSF14,DAG1,GPX1,RNF186,SLC26A6,USP4,GRB7,IP6K1,MON1A,NOTCH1,ORMDL3,NDUFAF3,IMPDH2,SEC16A,NR5A2,IP6K2,RBM5,FAM213B,RBM6,PEX13,UBA7,TMCO4,MED24,C11orf30,MST1R,PSMD3,SLC2A4RG,NXPE1,PARK7,RORC,ERRFI1,QRICH1,DALRD3,AHSA2,USP34
# PASS_UC_deLange2017	UC/Disease_M_cells	CCL20,FYB,FERMT1,FOSL2,CAPZA1,CTNNB1,RNF145,PIGR,MUC12,RPS29,CMTM6,USMG5,NPEPPS,FN1,RPL38,VMP1,BMP7,PPP1CB,DAZAP2,YWHAE,CDC42,RBM39,RPS27,EIF3E,CFLAR,PLBD1,CSRP2,RTN4,CTSE,RAB11A,TM7SF3,MYO6,ITGB1,TBCA,RPS26,KCNE3,MUC13,BZW1,SRSF5,RPL23,PTP4A2,MAL2,FAM84A,CAP1,ACTB,HSPA5,METAP2,B2M,CALR,HIGD1A
# PASS_IBD_deLange2017	UC/Disease_T_Lymphocytes	REL,CYLD,BRD7,CREM,STAT3,ZFP36L1,GPX1,LNPEP,NDFIP1,ITLN1,RPL37,ASH1L,SMCHD1,TNFRSF4,PTPRC,SELL,TNFRSF25,ETS1,TMEM258,CYTH1,VMP1,BRD4,NUCKS1,PRKCB,BATF,IRF2BP2,TNFRSF18,FYB,TRPS1,FAM89B,PRDM1,CAPZA1,CTNNB1,HSPE1,MSI2,DNAJC7,SKP1,CDC42SE2,HSPD1,PIM3,NSD1,RPL9,RPS29,USF2,SON,TCF7,CCR7,HINT1,PDCD1,PPP1CB
# PASS_IBD_deLange2017	UC/Disease_M_cells	FOSL2,RPL37,FERMT1,CCL20,MUC12,VMP1,RNF145,FYB,CAPZA1,CTNNB1,RPS29,ABHD17C,PPP1CB,CFLAR,YWHAE,DDX17,OLFM4,PLBD1,FN1,RPL23,NPEPPS,PIGR,B2M,SRSF5,CDC42,ITGB1,MAL2,ATP1B1,MUC13,APIP,GNAQ,CTSE,MIA,HSPA5,EIF4G2,CSRP2,SOX8,UBE2B,SPINK1,POMP,SPTBN1,RPL38,RAB11A,C12orf75,YWHAH,PARM1,SEC62,LEFTY1,KLF5,HIGD1A
# PASS_Multiple_sclerosis	MS/Disease_GABAergic	RAB3A,JUND,PRDX5,RPL5,KIF5A,SKP1,MAPK1,KPNB1,NDFIP1,DDX6,BANF1,TRMT112,ATP6V0A1,CHCHD2,SRP9,ZBTB38,RAB18,UBE2D3,TMEM160,FKBP2,C2orf69,PREX1,RPL24,HSPB1,RPS13,GDI2,STMN3,RPS9,YPEL3,SYNGR1,RPS6,CKB,NDRG4,HINT1,IRS2,DYNC1I2,MAPK8IP2,NUDC,NAP1L4,NDUFA12,RPL18,MYL6,BSG,UBE2B,CYCS,PITHD1,PEA15,THRA,ASNS,GRB2
# PASS_Multiple_sclerosis	MS/Disease_Glia	PRDX5,RPL5,SKP1,C3,NDFIP1,RGCC,CHCHD2,FKBP2,RPL24,HSPB1,RPS13,GNAI2,RPS9,DPYD,RPS6,CKB,NDRG4,HINT1,DYNC1I2,ABCA2,MEF2A,ABCA1,RPL18,MYL6,OLIG1,BSG,APOE,UBE2B,PEA15,PTPN13,RPL34,ATL1,NSF,YWHAB,CCNI,RPL7A,RPS8,WBP2,RPL37,ALDOA,CALM1,MPHOSPH8,NDUFS5,GAPDH,XPO1,CLTC,ARF1,APLP1,TUBA1A,RPL19
# PASS_Multiple_sclerosis	MS/Disease_Endothelial	IFITM2,IFNGR1,RGCC,HSPB1,RPS9,WARS,CKB,IFI16,MYL6,IQGAP1,PDIA6,RPL7A,RPL37,ALDOA,GAPDH,NEDD4,APLP1,ID3,RPL19,WWP1,CAP1,OOEP,RPL38,LPP,TXN,SLC26A3,RPL6,ACTG1,TPT1,ANXA5,GSTP1,GIMAP7,S100A6,UBB,WASF2,PLEKHA7,S100A11,CST3,ETV6,RPL28,MKL2,ACTB,BCL2L1,RPS2,ARL15,TPST2,RPS29,SMURF2,RPL15,SRP14
# PASS_Multiple_sclerosis	MS/Disease_Microglia	RPL5,MERTK,DPYD,TREM2,CKB,APOC1,ABCA1,RPL18,DENND4C,APOE,CALM1,GAPDH,ELL2,RPL19,MYO1E,RPL38,TIMP2,GPNMB,SLC26A3,EIF1,DDX5,TPT1,RPS25,HSP90AB1,CD63,CD74,RPL11,PDE3B,HS3ST4,FNIP2,IQGAP2,ARID5B,RPL28,LRP4,CDK14,CHN1,APLP2,RASGEF1B,MSR1,PSAP,CYBA,DMXL2,FTL,PPARG,TYROBP,ATP1B1,HNRNPA2B1,ATG7,FTH1,KCNMA1
# PASS_Alzheimers_Jansen2019	Alzheimers/Disease_Microglia	PICALM,APOC1,APOE,SLTM,EPS8,SYK,LHFPL2,TREM2,CD14,MYO1E,ADK,TANC2,LAPTM5,ITM2B,MBNL1,RAP1GDS1,CD81,OXR1,SNCA,LPAR6,CD74,ARMC9,SOCS6,SLC26A3,SERF2,MARCKS,RASA1,R3HDM1,ETV5,FCGBP,TAB2,RPL13,MAN2A1,PLEKHA7,RAP1A,SELPLG,HSP90AA1,RPL35,C3,MAML2,ITSN2,TMSB10,PPP1R12A,CAPZA2,RPS15,CST3,OSBPL3,ANKRD12,RPL28,CPED1
# UKB_460K.lung_FEV1FVCzSMOKE	asthma_disease/Fibroblast	DLC1,PTCH1,LOX,BMP4,DTWD1,NEXN,MRC2,CALD1,ADAMTS2,HTRA1,LRP1,FGF7,RERG,LTBP1,COL4A2,NUCKS1,LMCD1,LTBP4,PLXDC2,LTBP2,RHOBTB3,CAPZB,SFRP2,ANTXR1,IL1R1,PAPPA,ZFP36L2,P4HA2,TGFBR3,MFAP2,PEAK1,ITGA1,RBMS3,SEC11A,SERPING1,NR3C1,HIC1,IFITM2,ADD3,PLAC9,MYL9,HSPG2,MSRB3,FBN1,HMCN1,EVA1B,PHLDA3,CYBRD1,TFPI,ADAM33
# PASS_ChildOnsetAsthma_Ferreira2019	asthma_disease/T_Lymphocyte	FMNL1,RORA,GPR183,CFL1,CD52,CD247,CCDC85B,DIAPH1,SH3BGRL3,CREM,FXYD5,TAGAP,MYCBP2,AKAP13,ETS1,STK4,PRKCB,IQGAP2,OSTF1,RUNX3,CELF2,AKNA,RCSD1,SPOCK2,SNRPD2,SEPT1,LAT,SSR2,PRKCH,SPN,TNFRSF1B,PIP4K2A,HMHA1,ACTG1,ANKRD44,RGCC,TLN1,ICAM3,PPP1R12A,NAP1L1,CST7,SLA,VAMP2,TRAF3IP3,CHD1,JAK1,MYO1G,PTPN22,ANKRD12,GIMAP4
# IPF_Allen2020	Fibrosis/Disease_Mucous	MUC5B,SPINT1,CD151,CTSD,POLR2L,MUC1,MYDGF,MPZL2,LAMTOR4,KRT8,KRTCAP2,UQCRQ,ITM2B,HSBP1,SLC34A2,CRIP2,KRT18,SKP1,LY6E,SERF2,RPS27L,PAM,SYT8,NRP2,SPINT2,PERP,COX6B1,CD9,PRSS22,PDLIM4,DUSP23,CHL1,LMNA,TXNDC17,PRDX2,CYBA,CSNK1A1,SCPEP1,CLTA,DYNLL1,CRIP1,ATP1B1,FKBP2,ZFP36L1,RPL41,MIF,PDIA3,HSPA1A,EZR,COX4I1

# %% [markdown]
# # NMF programs

# %%
nmf_trait_pairs = [     ('PASS_Alzheimers_Jansen2019', 8, 'krasnow_pbmc'), # Classical
                        ('PASS_Alzheimers_Jansen2019', 15, 'krasnow_pbmc'), # Nonclassical
                        ('UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED', 5, 'krasnow_pbmc'), # cd4 t cells
                        ('UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED', 7, 'zheng_pbmc'), # IL2 signaling
                        ('PASS_Celiac', 7, 'zheng_pbmc'), # IL2 signaling
                        ('PASS_UC_deLange2017', 5, 'zheng_pbmc'), # MHC
                        ('PASS_Alzheimers_Jansen2019', 5, 'zheng_pbmc'), # MHC
                        ('PASS_Celiac', 2, 'ICA_bonemarrow'), # complement cascade
                        ('PASS_MDD_Wray2018', 0, 'allen_brain'), # SST
                        ('PASS_MDD_Wray2018', 1, 'allen_brain'), # PVALB
                        ('UKB_460K.body_WHRadjBMIz', 9, 'allen_brain'), # LAMP5
                        ('UKB_460K.body_WHRadjBMIz', 10, 'allen_brain'), # VIP
                        ('PASS_Neuroticism_Nagel2018', 2, 'allen_brain'), # IT
                        ('Fluid_intelligence_score', 4, 'allen_brain'), # L6
                        ('UKB_460K.cov_EDU_YEARS', 5, 'allen_brain'), # electron transport
                       ]

"""
Alzheimers Healthy Blood Classical Monocytes
Alzheimers Healthy Blood MHC-II antigen processing
Ulcerative colitis Healthy Blood MHC-II antigen processing 
Eczema Healthy Blood IL-2 signaling 
Rheumatoid arthritis Healthy Blood Complement cascade
Major Depressive Disorder Healthy Brain SST 
Major Depressive Disorder Healthy Brain PVALB 
Number of children born Healthy Brain LAMP5 
Number of children born Healthy Brain VIP
Neuroticism Healthy Brain Neurexin.Neureligin
Neuroticism Healthy Brain Addiction
"""
# Out:
# '\nAlzheimers Healthy Blood Classical Monocytes\nAlzheimers Healthy Blood MHC-II antigen processing\nUlcerative colitis Healthy Blood MHC-II antigen processing \nEczema Healthy Blood IL-2 signaling \nRheumatoid arthritis Healthy Blood Complement cascade\nMajor Depressive Disorder Healthy Brain SST \nMajor Depressive Disorder Healthy Brain PVALB \nNumber of children born Healthy Brain LAMP5 \nNumber of children born Healthy Brain VIP\nNeuroticism Healthy Brain Neurexin.Neureligin\nNeuroticism Healthy Brain Addiction\n'

# %%
for trait, nmf_program, tissue in nmf_trait_pairs:
    topgenes = compute_celltypeprogram_genes(magma_scores, None, trait, 'healthytopics', tissue=tissue, nmfprogram=celltype)
    print("%s\t%s\t%s\t%s"%(trait, tissue, nmf_program, ','.join(topgenes)))
# Out:
# PASS_Alzheimers_Jansen2019	krasnow_pbmc	8	MS4A6A,CD33,CR1,FCER1G,LILRA5,ALDOA,PILRA,CTSH,SPI1,LAMTOR4,CSGALNACT2,ITGAM,GRN,ANPEP,LILRB2,RAC1,SRGN,TREM1,PYCARD,GAPDH,TMEM170B,CD93,SAMSN1,CD55,CD14,FKBP5,FCGR2A,ROGDI,HNMT,SERPINA1,VNN1,NRG1,CD1D,GRINA,CPVL,FPR1,QPCT,FPR2,H2AFY,AQP9,FAM101B,ACSL1,CD68,NUDT16,NFE2,RNF130,TGFBI,ASPH,CD302,IFI30
# PASS_Alzheimers_Jansen2019	krasnow_pbmc	15	MS4A6A,MS4A4A,CD33,FCER1G,LILRA5,ALDOA,PILRA,CTSH,ABI3,SPI1,VASP,GRN,SCIMP,SLC16A3,LILRB2,RAC1,SRGN,CLTA,LRRC25,PYCARD,LILRB1,GAPDH,TAGLN,ADGRE2,CD55,PPP1R17,CD14,FCGR2A,ROGDI,HNMT,SERPINA1,PDK4,CSTB,CD300A,SIGLEC10,TNFRSF1B,DUSP6,TBC1D8,ITM2B,GRINA,CPVL,FPR1,SYNGR2,H2AFY,ARPC3,ARL4A,CD68,NUDT16,MIS18BP1,RNF130
# UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED	krasnow_pbmc	5	IL7R,STMN3,NDFIP1,LIME1,RPL5,CD6,ARHGAP15,GPR183,HMGN1,ADTRP,GIMAP7,CD52,RPS16,RPS11,RPL13A,FLT3LG,NOSIP,BCL2,TAGAP,TNFSF8,RPL38,CCR7,SIRPG,SELM,RPS3A,RPL41,TRABD2A,CD5,RPL37,RPL27A,FOXP1,LCK,SOD1,RHOH,BTG1,RPS10,TSTD1,SH3YL1,RPS23,TOB1,RPS8,TRAT1,CD27,CD3D,DPP4,CD3G,FBLN5,FCMR,AQP3,RPL10A
# UKB_460K.disease_ALLERGY_ECZEMA_DIAGNOSED	zheng_pbmc	7	CD247,RUNX3,PRR5L,ASCL2,IRF1,RAB37,CFL1,OASL,PTPRC,MYL6,SSBP4,ARPC2,TSEN54,SLC9A3R1,SH3BGRL3,ZNF683,SH2D2A,DUSP2,PTMS,GABARAPL1,SRGN,IFITM2,PRF1,S1PR5,DOK2,MANF,LAG3,FASLG,S100A10,CTSW,IL2RB,SELT,KLF6,PTGDR,KLRD1,ITGB7,BATF,CLEC2B,CD3D,CD3G,MATK,LITAF,BIN2,CTSC,EOMES,NKG7,XBP1,CEP78,RHOC,CALM1
# PASS_Celiac	zheng_pbmc	7	CX3CR1,CD247,PLEK,C12orf75,MRPL10,RUNX3,PYHIN1,IL10RA,FASLG,DSTN,RAC2,PTPRCAP,F2R,H3F3B,GGA1,IRF1,TBX21,IFNG,GZMK,CKLF,PRR5,DNAJC1,ANXA2,AOAH,B2M,GTF3C1,SPN,DOK2,MYL6,KLF6,ABI3,ITGB2,CD7,MYBL1,PTGDR,GAPDH,LPCAT1,FCRL6,MBP,CD8B,IL32,DUSP2,SLC1A7,PATL2,TNFSF14,OASL,ZNF683,CCDC107,RABAC1,ASCL2
# PASS_UC_deLange2017	zheng_pbmc	5	CARD9,FCGR2A,GPX1,IRF5,ANKRD65,LSP1,IL1R2,TSPO,RAC1,CTSS,TALDO1,HHEX,GPBAR1,FCGR2B,LYZ,NCF2,BASP1,TYMP,FCER1G,FAM26F,RHOC,ODF3B,RNASET2,CD1E,CLEC9A,AMICA1,CLEC10A,CTSZ,LAMTOR2,C1orf54,RHOG,BRI3,BLVRB,UTF1,ASGR2,RAB32,CD1D,LGALS1,CSTA,CFD,SCIMP,KIAA1598,SULF2,IGFBP7,IFI30,CD1C,PRELID1,BATF3,XCR1,LILRB2
# PASS_Alzheimers_Jansen2019	zheng_pbmc	5	MS4A6A,MS4A4A,CD33,FCER1G,PILRA,CTSH,SPI1,GRN,SCIMP,LILRB2,RAC1,SRGN,CACNA2D3,LILRB4,LRRC25,PYCARD,SERPINF2,RASSF4,PID1,FCGR2A,ROGDI,SERPINA1,CSTB,XCR1,CD1D,CYP2S1,CPVL,C1orf54,CLNK,QPCT,SYNGR2,H2AFY,ARPC3,IRF5,CRIP3,TP53I3,CD68,RNF130,TGFBI,CD302,IFI30,CD300C,CD74,EIF4A1,CLEC9A,LAMTOR2,MGST1,CAT,SDS,CSF3R
# PASS_Celiac	ICA_bonemarrow	2	DCC,PDIA5,PPCDC,IFNAR2,PNOC,NLRP14,CADM1,TNFRSF18,NPC2,ELL2,SEC61G,RPN1,HM13,ZNF215,TCN2,MYL2,DEPTOR,ALDOB,TMEM51,FOXP2,RPN2,C12orf77,PERP,SIL1,GJB2,COBLL1,TMEM258,MRPS31,MLEC,DNAJC1,ITM2C,CCR10,SPAG4,SCAMP5,POU2AF1,TMEM54,CDH15,MZB1,UFM1,HID1,KLF6,KLF13,ERLEC1,KCNMA1,TNFRSF13B,LMAN1,C1orf167,SEC61B,SRM,LSAMP
# PASS_MDD_Wray2018	allen_brain	0	TCF4,PCLO,ZNF462,TENM2,MAP7D1,ASTN2,PDE4B,RBFOX1,NTM,ZNF608,EYS,GRIA1,ROBO2,OPRD1,CC2D2A,NTRK2,BICD1,CDH9,RNF152,VAX1,RBMS3,SPATS2L,GLIPR1,RNF144B,AFAP1,FREM1,ATP1A3,PCSK5,DLGAP1,UTRN,CDH8,PITPNC1,SOX6,AHI1,SERINC5,OSBPL10,ARL4C,PHACTR2,CNTNAP2,ERC1,FAM20A,ZNF385D,PRRT4,CACNG2,CCDC136,PTPRG,KCNC1,BTBD11,TMEM200C,FGD3
# PASS_MDD_Wray2018	allen_brain	1	TCF4,TAOK3,MAP7D1,ADARB1,ASTN2,GABRA1,ZNF608,SRRM4,C7orf72,FHIT,EYS,GRIA1,ERBB4,SAMD13,TCAIM,SERPINI1,SGCZ,B4GALT6,NMNAT2,NTRK2,TMEM50B,SOX5,ZPBP,VAX1,RBMS3,SHISA9,RNF144B,AFAP1,OSBPL3,RPH3AL,ATP1A3,COG5,CHRD,DLGAP1,VDAC3,ESRRG,PITPNC1,SOX6,AHI1,VWC2,ARL4C,PHACTR2,INAFM1,CNTNAP2,ENTPD3,ERC1,ZNF385D,PRRT4,CACNG2,CCDC136
# UKB_460K.body_WHRadjBMIz	allen_brain	9	FLRT1,COL4A2,SBF2,BCKDHB,RRAS2,SYN2,BCL2,ADM,ARID5B,C1QTNF7,ADAMTSL3,COL4A1,SCUBE2,IGFBP3,ANO1,SEMA6D,PBX1,PROX1,TTC28,VCAN,DOCK3,ATP1B2,NRIP3,EFR3B,C2CD4A,PITPNC1,MAF,C8orf34,ST5,SEMA3F,RIN2,NPTXR,PDE8B,EXOSC10,BMP2,TCF4,SRM,VPS13C,HRH1,F2R,RUNX2,HECW2,RORA,TNFAIP8L3,ADAMTS2,IGF1,DOCK6,GRIA1,CCDC85A,METAP1D
# UKB_460K.body_WHRadjBMIz	allen_brain	10	FLRT1,SPCS1,MACROD1,WNT4,SLC22A3,TIMP2,ADAMTS6,NPR3,SCUBE2,IGFBP3,ROBO1,ANO1,SEMA6D,PROX1,PLCE1,TTC28,ATP1B2,NRIP3,PITPNC1,MAF,C8orf34,KCNT2,NPTXR,MCC,BMP2,TCF4,SRM,SELM,RXRG,ABCB5,EBPL,ABI3BP,B4GAT1,IGF1,SYT10,GRIA1,CCDC85A,METAP1D,KCNJ12,TMEM145,PLD3,ROBO2,HMP19,DCN,IQGAP2,TMTC2,SDK1,BSCL2,ALDOC,ISYNA1
# PASS_Neuroticism_Nagel2018	allen_brain	2	CELF4,GRM8,RBFOX1,SOX5,DCC,FBXL17,ARPP21,ASXL3,CADM2,MBD5,LINGO2,CENPW,GRM5,MSRA,RABGAP1L,SHISA9,VPS41,DLGAP2,POU6F2,SNCA,PCLO,KIRREL3,SATB2,CELF2,FOXP2,CDH2,FAM19A1,CCDC68,LRFN5,RAB27B,GPATCH8,NRXN1,OXR1,NEGR1,RGS6,ME1,CACNA2D3,BRINP3,ZNF804B,SYT16,NRG1,SYN2,PCDH9,SPATS2,STXBP5,SYT14,NECAB1,FOXP1,LRP1B,LARGE
# Fluid_intelligence_score	allen_brain	4	NEGR1,RBFOX1,AFF3,PPM1E,DPP4,CALN1,NCAM1,VWC2L,BCL11A,DGKZ,FAM160A1,PDE4D,SYT7,SLC17A7,PLCB1,CACNA1E,CORO6,TANC2,ZFHX3,CCDC92,EPHA5,GABRG3,KCNJ6,LRP1B,CCDC39,WNK2,PEX5L,PLCL2,NDST3,ANK2,ZNF385B,TEAD1,EFNA5,NLGN1,NRXN1,RALYL,CELF2,ZNF385D,SLC24A2,GRIK4,PTPRU,CTNNAL1,TRIM9,ASIC2,B3GALT1,KCNH3,GPR158,DGKI,CCSER1,LARGE
# UKB_460K.cov_EDU_YEARS	allen_brain	5	ATP6V0B,NSF,NDUFAF3,GPX1,STUB1,SOD1,MAP1LC3B,FBXL16,RPS26,TMX2,C11orf31,KLC1,ATP5G1,TBR1,COX6B1,CCT7,PIN1,PSMB5,UBL5,HNRNPK,DNAJA1,LYNX1,VPS29,HNRNPA1,SYT1,TTC9B,KCNS1,NECAB1,KLF9,UQCR10,MDH2,COX8A,CACYBP,HSPH1,ATXN7L3B,LRPAP1,ATP2A2,UQCRC1,ARPC5L,PJA2,YWHAB,BLOC1S2,RTN1,BNIP3,PLK2,DYNLL1,OTUB1,SMDT1,CCDC85B,STMN4

# %% [markdown]
# # joint NMF programs

# %%
nmf_trait_pairs = [     ('PASS_UC_deLange2017', 11, 'disease', 'colon'), # EGFR1 pathway
                        ('PASS_Multiple_sclerosis', 16, 'disease', 'ms'), # L2_3
                        ('PASS_Multiple_sclerosis', 21, 'disease', 'ms'), # Complement Cascade
                        ('PASS_Alzheimers_Jansen2019', 17, 'disease', 'alzheimers'), # Complement Cascade
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 31, 'healthy', 'asthma'), # macrophage neutrophil transition and asthma from asthma data
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 23, 'healthy', 'asthma'), # asthma data asthma trait fc epsilon receptor
                        ('UKB_460K.lung_FEV1FVCzSMOKE', 14, 'disease', 'asthma'), # asthma data lung capacity trait mapk signaling
                        ('PASS_Alzheimers_Jansen2019', 17, 'disease', 'alzheimers'), # Apelin signaling
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 31, 'healthy', 'asthma'), # Apelin signaling
                        ('PASS_ChildOnsetAsthma_Ferreira2019', 32, 'healthy', 'asthma'), # Apelin signaling
]

# %%
for trait, nmf_program, status, tissue in nmf_trait_pairs:
    topgenes = compute_celltypeprogram_genes(magma_scores, None, trait, 'jointtopic', tissue=tissue, nmfprogram=celltype, status=status)
    print("%s\t%s\t%s\t%s"%(trait, tissue, nmf_program, ','.join(topgenes)))
# Out:
# PASS_UC_deLange2017	colon	11	C1orf106,SLC26A3,NXPE4,NXPE1,UQCRC1,CLDN3,CLDN4,HNF4A,CDH1,TSPO,SATB2,SULT1A1,ITPKA,DGAT1,CHP2,PPP1R1B,MS4A12,RAPGEFL1,LSR,GOLM1,RAB25,TSPAN1,DHRS11,GPA33,FXYD3,RETSAT,SCNN1B,CDX1,TDP2,PRR15L,GUCA2B,CES2,CHCHD10,BEST4,KRTCAP3,IFT172,TSPAN3,PIGR,ASL,MUC12,TMEM171,DDC,FAM162A,CES3,USMG5,HSBP1L1,CKB,FAM3D,GUCA2A,NR2F6
# PASS_Multiple_sclerosis	ms	16	AHI1,STAT4,PITPNM2,SLC25A12,ANKRD33B,ICA1L,ROCK2,ARHGAP26,FAM163A,MED12L,RAPGEFL1,ICA1,CA10,MLIP,RCAN2,GAP43,ITPKA,KIAA1549L,CAMK2B,MAL2,CAMKK1,SLC8A1,RASAL2,NLK,STRBP,GNG2,EPB41L4B,RAPH1,SIDT1,PKIG,NEK10,PRICKLE1,C11orf87,NPTXR,CDYL2,GRM5,CCBE1,ITPR1,ANO3,PTPRR,ANKRD18B,PTH2R,FAM84A,STEAP2,KCNK1,LAMB1,SLC24A4,TARBP1,FBXW7,TMEM232
# PASS_Multiple_sclerosis	ms	21	CD37,RGS14,NCF4,RGS1,EAF2,CSF2RB,SOCS1,SLAMF7,ICAM3,FCRL2,ISG20,CD27,ST6GALNAC4,FCRL1,PECAM1,AEN,CD48,RPS9,IKZF3,RPS6,SLC16A6,NUDT22,SEC24D,GLCCI1,RPL18,FCRL5,HCLS1,FAM46C,RPL34,LRRK1,PTPN1,RPL7A,RPS8,JSRP1,ERP29,SND1,MANF,LCP1,OSTC,RPL19,POU2AF1,PROM2,OOEP,SEC61B,SRGN,NPC2,CITED2,PLCG2,SEC24A,LY96
# PASS_Alzheimers_Jansen2019	alzheimers	17	MS4A6A,SORL1,SYK,GHR,RAC1,CACNA1E,CACNA2D3,CADPS2,SNX32,SATB2,SPAG16,RIN3,SCN8A,LINGO2,LHFPL2,BLNK,BMPR2,SLC2A5,FAM160A1,SAMSN1,RPH3A,OCA2,ITGA8,CD14,CDK5R1,PRKCB,ARHGAP25,PGM2L1,DIP2A,MEF2A,ADK,TMEM163,TANC2,ULK3,PTPRR,LAPTM5,TBC1D1,TAGLN3,CADPS,NRG1,SFMBT2,RASEF,PPM1L,CAMKV,NR4A2,SCN2A,DPP10,DLGAP4,CLIP1,CACNA1B
# PASS_ChildOnsetAsthma_Ferreira2019	asthma	31	CCL20,IL6,GPR183,CFL1,CD52,S100A8,DOK3,FCER1G,TYMP,CAPG,NFKBIA,PSAP,SH3BGRL3,GRB2,FXYD5,FPR3,CLEC10A,NCF4,TFEC,S100A11,CLEC7A,S100A9,ENO1,FPR1,TIMP2,CTSB,THBD,FBP1,RGCC,CST3,FCGR2A,RIPK2,CTSA,COLGALT1,C1orf162,GLIPR2,ENG,ABL2,ARRB2,GNAI2,CD44,CD14,PPIA,CREG1,CCR1,IL10,IRF8,ARPC2,AQP9,FUOM
# PASS_ChildOnsetAsthma_Ferreira2019	asthma	23	GPR183,CFL1,CD52,FES,FCER1A,FCER1G,CAPG,NFKBIA,KRT1,SH3BGRL3,CREM,IL18R1,IL1RL1,FXYD5,IGFLR1,STAP1,HOXB2,AKAP13,CLEC10A,OSTF1,CTSW,CELF2,NCF4,BATF,CTTNBP2,LMNA,TMEM176B,LAT,FPR1,MATK,C10orf54,SPN,KCNH2,TNFSF12,NDST2,FCGR2A,ICAM3,RASGRP4,C1orf162,CST7,SLA,TRAF3IP3,ARRB2,RGS18,CD44,CD14,NBEAL1,PPIA,EIF3E,ADCYAP1
# UKB_460K.lung_FEV1FVCzSMOKE	asthma	14	DLC1,FOXA3,PDE2A,CALD1,COL4A2,NUCKS1,LMCD1,NR1D1,DST,DEPTOR,FLT1,NPNT,PRSS23,TAL1,PLAC9,TPM1,COL15A1,PABPC1,WFDC2,FOXN3,RRBP1,HOXD8,CCND1,NOSTRIN,IFITM3,SCGB1A1,ANXA2,ARGLU1,COL4A1,ADAMTS9,SLC12A2,NR4A2,TCF21,TCEA3,AGR2,KDR,ACTG1,TRIB1,GATA2,MEOX2,FAM83D,VMP1,LRRC32,SMAD9,SHE,DDX5,PDGFRB,EEF2,GPR4,ALPL
# PASS_Alzheimers_Jansen2019	alzheimers	17	MS4A6A,SORL1,SYK,GHR,RAC1,CACNA1E,CACNA2D3,CADPS2,SNX32,SATB2,SPAG16,RIN3,SCN8A,LINGO2,LHFPL2,BLNK,BMPR2,SLC2A5,FAM160A1,SAMSN1,RPH3A,OCA2,ITGA8,CD14,CDK5R1,PRKCB,ARHGAP25,PGM2L1,DIP2A,MEF2A,ADK,TMEM163,TANC2,ULK3,PTPRR,LAPTM5,TBC1D1,TAGLN3,CADPS,NRG1,SFMBT2,RASEF,PPM1L,CAMKV,NR4A2,SCN2A,DPP10,DLGAP4,CLIP1,CACNA1B
# PASS_ChildOnsetAsthma_Ferreira2019	asthma	31	CCL20,IL6,GPR183,CFL1,CD52,S100A8,DOK3,FCER1G,TYMP,CAPG,NFKBIA,PSAP,SH3BGRL3,GRB2,FXYD5,FPR3,CLEC10A,NCF4,TFEC,S100A11,CLEC7A,S100A9,ENO1,FPR1,TIMP2,CTSB,THBD,FBP1,RGCC,CST3,FCGR2A,RIPK2,CTSA,COLGALT1,C1orf162,GLIPR2,ENG,ABL2,ARRB2,GNAI2,CD44,CD14,PPIA,CREG1,CCR1,IL10,IRF8,ARPC2,AQP9,FUOM
# PASS_ChildOnsetAsthma_Ferreira2019	asthma	32	SH2B3,FMNL1,C1orf54,GPR183,IL1R2,CFL1,CD52,S100A8,ABI3,FES,FCER1A,FCER1G,TYMP,CAPG,PSAP,SH3BGRL3,FXYD5,FPR3,CLEC10A,TMEM176A,CELF2,NCF4,TFEC,CLEC7A,CTSC,S100A9,TMEM176B,FPR1,C10orf54,TIMP2,TNFRSF1B,CTSB,KCNMA1,THBD,FBP1,CST3,OLFML2B,FCGR2A,FAM26F,RIPK2,CTSA,COLGALT1,FPR2,C1orf162,SLA,PECAM1,ENG,ARRB2,GNAI2,ADAMTSL4
