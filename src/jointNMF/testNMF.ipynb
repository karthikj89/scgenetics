# %%
# %load_ext autoreload
# %autoreload 2

import jointNMF
import numpy as np

# %%
Wh = np.random.randint(0, high=5, size=(100,20))
Hh = np.random.randint(0, high=5, size=(20,1000))

Wshd = Wshh
Hshd = Hshh

Wd = np.random.randint(0, high=5, size=(100,20))
Hd = np.random.randint(0, high=5, size=(20,1000))


Xh = np.dot(Wh, Hh) + np.random.randn(100,1000)*0.001
Xd = np.dot(Wd, Hd) + np.random.randn(100,1000)*0.001

# %%
model = jointNMF.JointNMF(Xh, Xd, gamma=5, mu=.1)

# %%
np.mean(model.Wh), np.mean(model.Wd)
# Out:
# (3.501630655867195, 3.430250541596769)

# %%
model.solve()
# Out:
# Current Chi2=212393.6493, Previous Chi2=212833.0158,                       Change=0.2064% @ niters=0
# Current Chi2=208898.9341, Previous Chi2=209044.1092,                       Change=0.0694% @ niters=20
# Current Chi2=206271.5558, Previous Chi2=206393.4056,                       Change=0.0590% @ niters=40
# Current Chi2=203975.6719, Previous Chi2=204084.9806,                       Change=0.0536% @ niters=60
# Current Chi2=201884.3284, Previous Chi2=201985.0230,                       Change=0.0499% @ niters=80
# Current Chi2=199942.2461, Previous Chi2=200036.3423,                       Change=0.0470% @ niters=100
# Current Chi2=198118.3104, Previous Chi2=198207.0411,                       Change=0.0448% @ niters=120
# Current Chi2=196392.4169, Previous Chi2=196476.6187,                       Change=0.0429% @ niters=140
# Current Chi2=194750.4231, Previous Chi2=194830.7039,                       Change=0.0412% @ niters=160
# ...

# %%
np.mean(np.dot(model.Wh, model.Hh)), np.mean(np.dot(model.Wd, model.Hd))
# Out:
# (80.94615411618115, 78.31873764079984)

# %%
model.cost
# Out:
# 155889.64976873342

# %%
np.sum(model.Xh -np.dot(model.Wh, model.Hh))
# Out:
# -2624.719009956772

# %%
for i in range(Wh.shape[1]):
    for j in range(Wd.shape[1]):
        print(i, j, np.corrcoef(model.Wh[:,i], Wd[:,j])[0][1])
# Out:
# 0 0 -0.013039149992827358
# 0 1 0.05953108768463713
# 0 2 -0.0897043152735865
# 0 3 -0.09845033913970992
# 0 4 -0.07902741650865322
# 0 5 -0.1403744748458085
# 0 6 -0.16149524725211034
# 0 7 0.08933042710839831
# 0 8 -0.07391837407728698
# 0 9 -0.0183716977639691
# 0 10 -0.17406180467216145
# 0 11 -0.0037766354855198604
# 0 12 0.09575416018097245
# 0 13 0.053768915882761836
# 0 14 -0.03852172460880543
# 0 15 0.05363288201614817
# 0 16 0.05273472615119536
# 0 17 -0.0721350486574278
# 0 18 -0.011408770384366038
# 0 19 0.04037232044694223
# 1 0 0.015698975298899694
# 1 1 0.12881284346737965
# 1 2 0.06457457844814178
# 1 3 -0.06568098155561583
# 1 4 0.03532860324099989
# 1 5 0.047778835767254606
# 1 6 0.10375593119759235
# 1 7 0.07038059756272724
# 1 8 0.04029656923031647
# 1 9 -0.03696003263431274
# 1 10 -0.0022646505362596088
# 1 11 0.12413845489139431
# 1 12 -0.03773784594862717
# 1 13 0.05928165577382385
# 1 14 -0.018865337488013147
# 1 15 -0.104536043014605
# ...

# %%
for i in range(Wh.shape[1]):
    for j in range(Wh.shape[1]):
        print(i, j, np.corrcoef(model.Wh[:,i], Wh[:,j])[0][1])
# Out:
# 0 0 0.027463387918000563
# 0 1 -0.08199665058354044
# 0 2 0.09922691475929041
# 0 3 -0.032247393875467545
# 0 4 -0.00998748760929938
# 0 5 0.1631282453925046
# 0 6 -0.08735441593945013
# 0 7 -0.01582842496167923
# 0 8 -0.03772305609590657
# 0 9 0.749039828904855
# 0 10 0.4384621994393786
# 0 11 -0.026686000880679253
# 0 12 0.1137369956621641
# 0 13 0.17624137399997475
# 0 14 0.07753545139629729
# 0 15 0.09464401546412939
# 0 16 0.05434816686919008
# 0 17 0.43368381917239185
# 0 18 0.25343280559231723
# 0 19 -0.21095883953810124
# 1 0 0.13632555471017202
# 1 1 0.5292957778374382
# 1 2 0.19960054336734823
# 1 3 -0.20081920588249932
# 1 4 0.41945225609674464
# 1 5 -0.169492620107557
# 1 6 -0.36584204111904556
# 1 7 0.02024012926796951
# 1 8 0.31825254908807177
# 1 9 -0.038705947074795556
# 1 10 -0.23514061890093077
# 1 11 -0.07058506547011907
# 1 12 -0.40790915314042214
# 1 13 0.01845129087451593
# 1 14 0.3245118071368837
# 1 15 0.017096886850818987
# 1 16 0.010560916488805082
# ...

# %%
for i in range(Wd.shape[1]):
    for j in range(Wd.shape[1]):
        print(i, j, np.corrcoef(model.Wd[:,i], model.Wd[:,j])[0][1])
# Out:
# 0 0 1.0
# 0 1 0.1595313264158713
# 0 2 -0.013095669915293009
# 0 3 -0.004966864886210596
# 0 4 0.07335826551786734
# 0 5 -0.16555819022099655
# 0 6 0.10236799971643011
# 0 7 -0.09239171802457485
# 0 8 0.0019757381136562818
# 0 9 -0.0606475044562286
# 0 10 -0.18144426934480903
# 0 11 -0.03941161034609354
# 0 12 -0.09289939577543617
# 0 13 0.09152621132180991
# 0 14 0.21813796841063657
# 0 15 -0.014524543201564244
# 0 16 0.04195881183662486
# 0 17 0.09453053499924806
# 0 18 0.165501752371501
# 0 19 -0.024276907514316493
# 1 0 0.15953132641587134
# 1 1 1.0
# 1 2 -0.18339611668164646
# 1 3 0.10586534425610403
# 1 4 0.17943203409817246
# 1 5 -0.0463549221512883
# 1 6 -0.018997929448129967
# 1 7 -0.044066239203644594
# 1 8 0.0429320343689127
# 1 9 -0.11736004739444132
# 1 10 -0.09396980073363818
# 1 11 -0.044894983162472535
# 1 12 0.001569944180612431
# 1 13 0.029550964959094
# 1 14 0.12106413683016021
# 1 15 -0.012248790507155062
# 1 16 -0.148703084940121
# 1 17 0.07054272948363353
# ...
